# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv('c:/Users/Admin/Documents/Data Set/Project DataSet/fremont-bridge.csv')
df.head()
# Out:
#              Date  West  East
# 0  10/3/2012 0:00   4.0   9.0
# 1  10/3/2012 1:00   4.0   6.0
# 2  10/3/2012 2:00   1.0   1.0
# 3  10/3/2012 3:00   2.0   3.0
# 4  10/3/2012 4:00   6.0   1.0

# %%
df.columns
# Out:
# Index(['Date', 'West', 'East'], dtype='object')

# %%
df.columns=['Date','West','East']

# %%
df['Total']=df['West']+df['East']

# %%
df.head()
# Out:
#              Date  West  East  Total
# 0  10/3/2012 0:00   4.0   9.0   13.0
# 1  10/3/2012 1:00   4.0   6.0   10.0
# 2  10/3/2012 2:00   1.0   1.0    2.0
# 3  10/3/2012 3:00   2.0   3.0    5.0
# 4  10/3/2012 4:00   6.0   1.0    7.0

# %%
df.dropna().describe()
# Out:
#                West          East         Total
# count  45976.000000  45976.000000  45976.000000
# mean      54.712306     55.479315    110.191622
# std       72.935797     80.232055    139.189603
# min        0.000000      0.000000      0.000000
# 25%        7.000000      7.000000     15.000000
# 50%       29.000000     28.000000     60.000000
# 75%       72.000000     68.000000    144.000000
# max      854.000000    717.000000   1165.000000

# %%
df.shape
# Out:
# (45984, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45984 entries, 0 to 45983
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    45984 non-null  object
#  1   West    45976 non-null  float64
#  2   East    45976 non-null  float64
#  3   Total   45976 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# Date     0
# West     8
# East     8
# Total    8
# dtype: int64

# %%
x=df['West'].mean()
x
# Out:
# 54.71230642074126

# %%
df['West'].std()
# Out:
# 72.9357967277195

# %%
def fun(df,var,x):
    df['West_1'] = df['West'].fillna(x)
    
fun(df,'West',x)

# %%
df.West.isnull().sum()
# Out:
# 8

# %%
df.West_1.isnull().sum()
# Out:
# 0

# %%
df=df.drop(['West'],axis=1)
df.head()
# Out:
#              Date  East  Total  West_1
# 0  10/3/2012 0:00   9.0   13.0     4.0
# 1  10/3/2012 1:00   6.0   10.0     4.0
# 2  10/3/2012 2:00   1.0    2.0     1.0
# 3  10/3/2012 3:00   3.0    5.0     2.0
# 4  10/3/2012 4:00   1.0    7.0     6.0

# %%
y=df['East'].mean()
y
# Out:
# 55.47931529493649

# %%
df['East'].std()
# Out:
# 80.23205500230816

# %%
def fun(df,var,y):
    df['East_1'] = df['East'].fillna(y)
    
fun(df,'East',y)

# %%
df.East.isnull().sum()
# Out:
# 8

# %%
df.East_1.isnull().sum()
# Out:
# 0

# %%
df=df.drop(['East'],axis=1)
df.head()
# Out:
#              Date  Total  West_1  East_1
# 0  10/3/2012 0:00   13.0     4.0     9.0
# 1  10/3/2012 1:00   10.0     4.0     6.0
# 2  10/3/2012 2:00    2.0     1.0     1.0
# 3  10/3/2012 3:00    5.0     2.0     3.0
# 4  10/3/2012 4:00    7.0     6.0     1.0

# %%
z=df['Total'].mean()
z
# Out:
# 110.19162171567774

# %%
df['Total'].std()
# Out:
# 139.18960320475585

# %%
def fun(df,var,z):
    df['Total_1'] = df['Total'].fillna(z)
    
fun(df,'total',z)

# %%
df.Total.isnull().sum()
# Out:
# 8

# %%
df.Total_1.isnull().sum()
# Out:
# 0

# %%
df=df.drop(['Total'],axis=1)
df.head()
# Out:
#              Date  West_1  East_1  Total_1
# 0  10/3/2012 0:00     4.0     9.0     13.0
# 1  10/3/2012 1:00     4.0     6.0     10.0
# 2  10/3/2012 2:00     1.0     1.0      2.0
# 3  10/3/2012 3:00     2.0     3.0      5.0
# 4  10/3/2012 4:00     6.0     1.0      7.0

# %%
df['date']=pd.to_datetime(df['Date'])
df['day']=df['date'].dt.day
df['month']=df['date'].dt.month
df['year']=df['date'].dt.year

# %%
df=df.drop(['date','Date'],axis=1)
df.head()
# Out:
#    West_1  East_1  Total_1  day  month  year
# 0     4.0     9.0     13.0    3     10  2012
# 1     4.0     6.0     10.0    3     10  2012
# 2     1.0     1.0      2.0    3     10  2012
# 3     2.0     3.0      5.0    3     10  2012
# 4     6.0     1.0      7.0    3     10  2012

# %%
df['day'].value_counts()
# Out:
# 16    1512
# 17    1512
# 6     1512
# 7     1512
# 8     1512
# 9     1512
# 10    1512
# 11    1512
# 12    1512
# 13    1512
# 14    1512
# 15    1512
# 3     1512
# 18    1512
# 4     1512
# 19    1512
# 20    1512
# 21    1512
# 22    1512
# 23    1512
# 24    1512
# 25    1512
# 26    1512
# 27    1512
# 28    1512
# 5     1512
# 2     1488
# 1     1488
# 29    1416
# 30    1392
# 31     888
# Name: day, dtype: int64

# %%
df['month'].value_counts()
# Out:
# 12    4464
# 10    4416
# 11    4320
# 8     3720
# 7     3720
# 5     3720
# 3     3720
# 1     3720
# 9     3600
# 6     3600
# 4     3600
# 2     3384
# Name: month, dtype: int64

# %%
df['year'].value_counts()
# Out:
# 2016    8784
# 2015    8760
# 2014    8760
# 2013    8760
# 2017    8760
# 2012    2160
# Name: year, dtype: int64

# %%
sn.pairplot(df)

# %%
sn.set()

# %%
df.plot()
plt.xlabel('counts')
plt.ylabel('Hourly Bicycle count')
plt.grid(True,c='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sn.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    West_1  East_1  Total_1  day  month  year
# 0     4.0     9.0     13.0    3     10  2012
# 1     4.0     6.0     10.0    3     10  2012
# 2     1.0     1.0      2.0    3     10  2012
# 3     2.0     3.0      5.0    3     10  2012
# 4     6.0     1.0      7.0    3     10  2012

# %%
df.isnull().sum()
# Out:
# West_1     0
# East_1     0
# Total_1    0
# day        0
# month      0
# year       0
# dtype: int64

# %%
x=df.drop(['Total_1'],axis=1)
y=df['Total_1']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
xtrain.head()
# Out:
#        West_1  East_1  day  month  year
# 1330     39.0    29.0   27     11  2012
# 27373    16.0    16.0   17     11  2015
# 9512     27.0    23.0    3     11  2013
# 24873   158.0   112.0    5      8  2015
# 28396     3.0     2.0   30     12  2015

# %%
ytrain.head()
# Out:
# 1330      68.0
# 27373     32.0
# 9512      50.0
# 24873    270.0
# 28396      5.0
# Name: Total_1, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg= LinearRegression()
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_test_pred = reg.predict(xtest)

# %%
y_test_pred
# Out:
# array([  5.,  42.,   5., ..., 124.,   6.,  96.])

# %%
ytest
# Out:
# 628        5.0
# 36200     42.0
# 11690      5.0
# 19599     39.0
# 36614     48.0
#          ...
# 40139     83.0
# 7519     345.0
# 31477    124.0
# 18337      6.0
# 8622      96.0
# Name: Total_1, Length: 15175, dtype: float64

# %%
reg.coef_
# Out:
# array([ 7.27199554e+01,  8.02739404e+01, -9.06936402e-16,  8.81233426e-16,
#         2.90328727e-15])

# %%
reg.intercept_
# Out:
# 110.28118270987628

# %%
reg.score(xtrain,ytrain)
# Out:
# 1.0

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest,y_test_pred)
# Out:
# 1.0
